# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
from collections import Counter
#print(os.listdir("../input"))

# %%
data = pd.read_csv('/Volumes/Samsung_T5/Обучение/skillfactory/data-proj1.csv')
data.head(5)
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
len(data)
# Out:
# 1890

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1890 entries, 0 to 1889
# Data columns (total 17 columns):
# imdb_id                 1890 non-null object
# popularity              1890 non-null float64
# budget                  1890 non-null int64
# revenue                 1890 non-null int64
# original_title          1890 non-null object
# cast                    1890 non-null object
# director                1890 non-null object
# tagline                 1890 non-null object
# overview                1890 non-null object
# runtime                 1890 non-null int64
# genres                  1890 non-null object
# production_companies    1890 non-null object
# release_date            1890 non-null object
# vote_count              1890 non-null int64
# vote_average            1890 non-null float64
# release_year            1890 non-null int64
# profit                  1890 non-null int64
# dtypes: float64(2), int64(6), object(9)
# memory usage: 251.1+ KB

# %% [markdown]
# # Предобработка датасета

# %%
answer_ls = [] # создадим список с ответами. сюда будем добавлять ответы по мере прохождения теста
# сюда можем вписать создание новых колонок в датасете

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?
# Варианты ответов:
# 1. The Dark Knight Rises (tt1345836)
# 2. Spider-Man 3 (tt0413300)
# 3. Avengers: Age of Ultron (tt2395427)
# 4. The Warrior's Way	(tt1032751)
# 5. Pirates of the Caribbean: On Stranger Tides (tt1298650)

# %%
data[data['budget'] == data.budget.max()].original_title
# Out:
# 491    The Warrior's Way
# Name: original_title, dtype: object

# %%
# тут вводим ваш ответ и добавлем в его список ответов (сейчас для примера стоит "1")
answer_ls.append(data[data['budget'] == data.budget.max()].original_title)

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)
# 1. The Lord of the Rings: The Return of the King	(tt0167260)
# 2. Gods and Generals	(tt0279111)
# 3. King Kong	(tt0360717)
# 4. Pearl Harbor	(tt0213149)
# 5. Alexander	(tt0346491)

# %%
data[data['runtime'] == data.runtime.max()].original_title
# Out:
# 1158    Gods and Generals
# Name: original_title, dtype: object

# %%
answer_ls.append(data[data['runtime'] == data.runtime.max()].original_title)

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)
# Варианты ответов:
#
# 1. Home on the Range	tt0299172
# 2. The Jungle Book 2	tt0283426
# 3. Winnie the Pooh	tt1449283
# 4. Corpse Bride	tt0121164
# 5. Hoodwinked!	tt0443536

# %%
data[data['runtime'] == data.runtime.min()].original_title
# Out:
# 769    Winnie the Pooh
# Name: original_title, dtype: object

# %%
answer_ls.append(data[data['runtime'] == data.runtime.min()].original_title)

# %% [markdown]
# # 4. Средняя длительность фильма?
#
# Варианты ответов:
# 1. 115
# 2. 110
# 3. 105
# 4. 120
# 5. 100

# %%
print(data.runtime.mean())
print(data.runtime.sum()/data.runtime.count())
# Out:
# 109.65343915343915
# 109.65343915343915

# %%
answer_ls.append(round(data.runtime.mean()))

# %% [markdown]
# # 5. Средняя длительность фильма по медиане?
# Варианты ответов:
# 1. 106
# 2. 112
# 3. 101
# 4. 120
# 5. 115

# %%
data.runtime.median()
# Out:
# 106.5

# %%
answer_ls.append(round(data.runtime.median()))

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# Варианты ответов:
# 1. The Avengers	tt0848228
# 2. Minions	tt2293640
# 3. Star Wars: The Force Awakens	tt2488496
# 4. Furious 7	tt2820852
# 5. Avatar	tt0499549

# %%
data['profit'] = data['revenue'] - data['budget']
display(data.head(3))
data[data['profit'] == data.profit.max()]
# Out:
#      imdb_id  popularity     budget     revenue      original_title  \
# 0  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
#
#                       tagline  \
# 0           The park is open.
# 1          What a Lovely Day.
# 2  One Choice Can Destroy You
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
#
# ...

# %%
answer_ls.append(data[data['profit'] == data.profit.max()].original_title)

# %% [markdown]
# # 7. Какой фильм самый убыточный?
# Варианты ответов:
# 1. Supernova tt0134983
# 2. The Warrior's Way tt1032751
# 3. Flushed Away	tt0424095
# 4. The Adventures of Pluto Nash	tt0180052
# 5. The Lone Ranger	tt1210819

# %%
#data[data['revenue'] == data.revenue.min()]

data[data['profit'] == data.profit.min()]
# Out:
#        imdb_id  popularity     budget   revenue     original_title  \
# 491  tt1032751     0.25054  425000000  11087569  The Warrior's Way
#
#                                                   cast    director  \
# 491  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...  Sngmoo Lee
#
#                      tagline  \
# 491  Assassin. Hero. Legend.
#
#                                               overview  runtime  \
# 491  An Asian assassin (Dong-gun Jang) is forced to...      100
#
#                                         genres      production_companies  \
# 491  Adventure|Fantasy|Action|Western|Thriller  Boram Entertainment Inc.
#
#     release_date  vote_count  vote_average  release_year     profit
# 491    12/2/2010          74           6.4          2010 -413912431

# %%
answer_ls.append(data[data['profit'] == data.profit.min()].original_title)

# %% [markdown]
# # 8. Сколько всего фильмов в прибыли?
# Варианты ответов:
# 1. 1478
# 2. 1520
# 3. 1241
# 4. 1135
# 5. 1398

# %%
bestfilms = data[data['profit'] > 0]
bestfilms.head(2)
bestfilms.count()
# Out:
# imdb_id                 1478
# popularity              1478
# budget                  1478
# revenue                 1478
# original_title          1478
# cast                    1478
# director                1478
# tagline                 1478
# overview                1478
# runtime                 1478
# genres                  1478
# production_companies    1478
# release_date            1478
# vote_count              1478
# vote_average            1478
# release_year            1478
# profit                  1478
# dtype: int64

# %%
answer_ls.append(bestfilms.count())

# %% [markdown]
# # 9. Самый прибыльный фильм в 2008 году?
# Варианты ответов:
# 1. Madagascar: Escape 2 Africa	tt0479952
# 2. Iron Man	tt0371746
# 3. Kung Fu Panda	tt0441773
# 4. The Dark Knight	tt0468569
# 5. Mamma Mia!	tt0795421

# %%
data[data['release_year'] == 2008].sort_values(['profit'],ascending=False).head(1)

#ss = data[(data['release_year'] == 2008) & (data['profit'] == data.profit.max())]
#& (bestfilms['profit'] == bestfilms.profit.max())
# Out:
#        imdb_id  popularity     budget     revenue   original_title  \
# 600  tt0468569    8.466668  185000000  1001921825  The Dark Knight
#
#                                                   cast           director  \
# 600  Christian Bale|Michael Caine|Heath Ledger|Aaro...  Christopher Nolan
#
#              tagline                                           overview  \
# 600  Why So Serious?  Batman raises the stakes in his war on crime. ...
#
#      runtime                       genres  \
# 600      152  Drama|Action|Crime|Thriller
#
#                                   production_companies release_date  \
# 600  DC Comics|Legendary Pictures|Warner Bros.|Syncopy    7/16/2008
#
#      vote_count  vote_average  release_year     profit
# 600        8432           8.1          2008  816921825

# %%
answer_ls.append("The Dark Knight")

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 (включительно)?
# Варианты ответов:
# 1. Winter's Tale	tt1837709
# 2. Stolen	tt1656186
# 3. Broken City	tt1235522
# 4. Upside Down	tt1374992
# 5. The Lone Ranger	tt1210819

# %%
data[(data['release_year'] > 2011) & (data['release_year'] < 2015)].sort_values(['profit'],ascending=True).head(5)
# Out:
#         imdb_id  popularity     budget   revenue  \
# 1246  tt1210819    1.214510  255000000  89289910
# 1215  tt0790736    1.689869  130000000  61648500
# 1008  tt1374992    1.690572   60000000   8106475
# 1303  tt0884726    0.354271   70000000  18662027
# 1236  tt1308729    1.319947   55000000   9489829
#
#                        original_title  \
# 1246                  The Lone Ranger
# 1215                         R.I.P.D.
# 1008                      Upside Down
# 1303  Legends of Oz: Dorothy's Return
# 1236               Bullet to the Head
#
#                                                    cast            director  \
# 1246  Johnny Depp|Armie Hammer|William Fichtner|Hele...      Gore Verbinski
# 1215  Jeff Bridges|Ryan Reynolds|Kevin Bacon|Stephan...    Robert Schwentke
# 1008  Kirsten Dunst|Jim Sturgess|Timothy Spall|James...  Juan Diego Solanas
# 1303  Lea Michele|Dan Aykroyd|Patrick Stewart|Hugh D...      Dan St. Pierre
# ...

# %%
answer_ls.append("The Lone Ranger")

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?
# Варианты ответов:
# 1. Action
# 2. Adventure
# 3. Drama
# 4. Comedy
# 5. Thriller

# %%
pd.DataFrame(data.genres.str.split('|').tolist()).stack().value_counts()
# Out:
# Drama              782
# Comedy             683
# Thriller           597
# Action             583
# Adventure          416
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            223
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             20
# Documentary          8
# Foreign              2
# dtype: int64

# %%
answer_ls.append("Drama")

# %% [markdown]
# # 12. Какого жанра среди прибыльных фильмов больше всего?
# Варианты ответов:
# 1. Drama
# 2. Comedy
# 3. Action
# 4. Thriller
# 5. Adventure

# %%
pd.DataFrame(data[data['profit'] > 0].genres.str.split('|').tolist()).stack().value_counts().head()
# Out:
# Drama        560
# Comedy       551
# Thriller     446
# Action       444
# Adventure    337
# dtype: int64

# %%
answer_ls.append("Drama")

# %% [markdown]
# # 13. Кто из режиссеров снял больше всего фильмов?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Ridley Scott
# 3. Steven Soderbergh
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
data.groupby(['director'])['imdb_id'].count().sort_values(ascending=False).head()
# Out:
# director
# Steven Soderbergh    13
# Ridley Scott         12
# Clint Eastwood       12
# Shawn Levy           10
# Steven Spielberg     10
# Name: imdb_id, dtype: int64

# %%
answer_ls.append("Steven Soderbergh")

# %%
new_df = pd.DataFrame(columns = ['director', 'profit', 'imdb_id', 'original_title'])

def formnewframe(def_list):
    directors = def_list.director.split('|')
    for i in directors:
        new_df.loc[len(new_df)] = [i,def_list.profit,def_list.imdb_id,def_list.original_title]
        


for i in range(len(data)):
    formnewframe(data.iloc[i])
    
new_df.head(15)
# Out:
#                           director      profit    imdb_id  \
# 0                  Colin Trevorrow  1363528810  tt0369610
# 1                    George Miller   228436354  tt1392190
# 2                 Robert Schwentke   185238201  tt2908446
# 3                      J.J. Abrams  1868178225  tt2488496
# 4                        James Wan  1316249360  tt2820852
# 5   Alejandro GonzÃ¡lez IÃ±Ã¡rritu   397950503  tt1663202
# 6                      Alan Taylor   285603537  tt1340138
# 7                     Ridley Scott   487380321  tt3659388
# 8                       Kyle Balda  1082730962  tt2293640
# 9                    Pierre Coffin  1082730962  tt2293640
# 10                     Pete Docter   678708609  tt2096673
# 11                      Sam Mendes   635674609  tt2379713
# 12                  Lana Wachowski     7987720  tt1617661
# 13                 Lilly Wachowski     7987720  tt1617661
# 14                    Alex Garland    21869414  tt0470752
#
#                   original_title
# ...

# %%
new_df.groupby(['director'])['imdb_id'].count().sort_values(ascending=False).head()
# Out:
# director
# Steven Soderbergh    13
# Ridley Scott         12
# Clint Eastwood       12
# Robert Rodriguez     11
# Shawn Levy           10
# Name: imdb_id, dtype: int64

# %% [markdown]
# # 14. Кто из режиссеров снял больше всего Прибыльных фильмов?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Clint Eastwood
# 3. Steven Spielberg
# 4. Ridley Scott
# 5. Christopher Nolan

# %%
new_df[new_df['profit'] > 0].groupby(['director'])['imdb_id'].count().sort_values(ascending=False).head()
# Out:
# director
# Ridley Scott         12
# Clint Eastwood       10
# Steven Spielberg     10
# Steven Soderbergh    10
# Tim Burton            9
# Name: imdb_id, dtype: int64

# %%
answer_ls.append('Ridley Scott')

# %% [markdown]
# # 15. Кто из режиссеров принес больше всего прибыли?
# Варианты ответов:
# 1. Steven Spielberg
# 2. Christopher Nolan
# 3. David Yates
# 4. James Cameron
# 5. Peter Jackson

# %%
data.groupby(['director'])['profit'].sum().sort_values(ascending=False).head()
# Out:
# director
# Peter Jackson        5202593685
# David Yates          3379295625
# Christopher Nolan    3162548502
# J.J. Abrams          2839169916
# Michael Bay          2760938960
# Name: profit, dtype: int64

# %%
new_df.groupby(['director'])['profit'].sum().sort_values(ascending=False).head()
# Out:
# director
# Peter Jackson        5202593685
# David Yates          3379295625
# Christopher Nolan    3162548502
# J.J. Abrams          2839169916
# Michael Bay          2760938960
# Name: profit, dtype: int64

# %%
answer_ls.append("Peter Jackson")

# %% [markdown]
# # 16. Какой актер принес больше всего прибыли?
# Варианты ответов:
# 1. Emma Watson
# 2. Johnny Depp
# 3. Michelle Rodriguez
# 4. Orlando Bloom
# 5. Rupert Grint

# %%
data.head(3)
# Out:
#      imdb_id  popularity     budget     revenue      original_title  \
# 0  tt0369610   32.985763  150000000  1513528810      Jurassic World
# 1  tt1392190   28.419936  150000000   378436354  Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201           Insurgent
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
#
#                       tagline  \
# 0           The park is open.
# 1          What a Lovely Day.
# 2  One Choice Can Destroy You
#
#                                             overview  runtime  \
# 0  Twenty-two years after the events of Jurassic ...      124
# 1  An apocalyptic story set in the furthest reach...      120
# 2  Beatrice Prior must confront her inner demons ...      119
#
# ...

# %%
new_df = pd.DataFrame(columns = ['actor', 'original_title', 'profit', 'release_date', 'budget'])

def formnewframe(def_list):
    actors = def_list.cast.split('|')
    for i in actors:
        new_df.loc[len(new_df)] = [i,def_list.original_title,def_list.profit,def_list.release_date,def_list.budget ]
        

for i in range(len(data)):
    formnewframe(data.iloc[i])
    
new_df.head(15)
# Out:
#                   actor      original_title      profit release_date  \
# 0           Chris Pratt      Jurassic World  1363528810     6/9/2015
# 1   Bryce Dallas Howard      Jurassic World  1363528810     6/9/2015
# 2           Irrfan Khan      Jurassic World  1363528810     6/9/2015
# 3     Vincent D'Onofrio      Jurassic World  1363528810     6/9/2015
# 4         Nick Robinson      Jurassic World  1363528810     6/9/2015
# 5             Tom Hardy  Mad Max: Fury Road   228436354    5/13/2015
# 6       Charlize Theron  Mad Max: Fury Road   228436354    5/13/2015
# 7      Hugh Keays-Byrne  Mad Max: Fury Road   228436354    5/13/2015
# 8        Nicholas Hoult  Mad Max: Fury Road   228436354    5/13/2015
# 9           Josh Helman  Mad Max: Fury Road   228436354    5/13/2015
# 10     Shailene Woodley           Insurgent   185238201    3/18/2015
# 11           Theo James           Insurgent   185238201    3/18/2015
# 12         Kate Winslet           Insurgent   185238201    3/18/2015
# ...

# %%
new_df.groupby(['actor'])['profit'].sum().sort_values(ascending=False).head(10)
# Out:
# actor
# Emma Watson           6666245597
# Daniel Radcliffe      6514990281
# Rupert Grint          6408638290
# Ian McKellen          6087375777
# Robert Downey Jr.     5316030161
# Orlando Bloom         5148578162
# Johnny Depp           4776417000
# Ralph Fiennes         4739260140
# Michelle Rodriguez    4608031235
# Anne Hathaway         4490351538
# Name: profit, dtype: int64

# %%
answer_ls.append("Emma Watson")

# %% [markdown]
# # 17. Какой актер принес меньше всего прибыли в 2012 году?
# Варианты ответов:
# 1. Nicolas Cage
# 2. Danny Huston
# 3. Kirsten Dunst
# 4. Jim Sturgess
# 5. Sami Gayle

# %%
ss = new_df[new_df.release_date.str.contains('2012')]

ss.groupby(['actor'])['profit'].sum().sort_values(ascending=True).head()
# Out:
# actor
# Kirsten Dunst    -68109207
# Heidi Hawkins    -51893525
# James Kidnie     -51893525
# Timothy Spall    -51893525
# Malin Ã…kerman   -43733509
# Name: profit, dtype: int64

# %%
answer_ls.append("Kirsten Dunst")

# %% [markdown]
# # 18. Какой актер снялся в большем количестве высокобюджетных фильмов? (в фильмах где бюджет выше среднего по данной выборке)
# Варианты ответов:
# 1. Tom Cruise
# 2. Mark Wahlberg
# 3. Matt Damon
# 4. Angelina Jolie
# 5. Adam Sandler

# %%
new_df[new_df.budget > new_df.budget.mean()].groupby(["actor"])['original_title'].count().sort_values(ascending=False).head()
# Out:
# actor
# Matt Damon        18
# Adam Sandler      17
# Angelina Jolie    16
# Eddie Murphy      15
# Tom Cruise        15
# Name: original_title, dtype: int64

# %%
new_df.budget.mean()
# Out:
# 54537412.46796569

# %%
answer_ls.append("Matt Damon")

# %% [markdown]
# # 19. В фильмах какого жанра больше всего снимался Nicolas Cage?
# Варианты ответа:
# 1. Drama
# 2. Action
# 3. Thriller
# 4. Adventure
# 5. Crime

# %%
ss = pd.DataFrame(data[data['cast'].str.contains('Nicolas Cage')].genres.str.split('|').tolist())
ss.stack().value_counts()
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Animation           3
# Family              3
# Mystery             3
# History             2
# War                 1
# Romance             1
# Horror              1
# dtype: int64

# %%
answer_ls.append("Action")

# %% [markdown]
# # 20. Какая студия сняла больше всего фильмов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
ss = pd.DataFrame(data.production_companies.str.split('|').tolist())
ss.stack().value_counts().head(10)
# Out:
# Universal Pictures                        173
# Warner Bros.                              168
# Paramount Pictures                        122
# Columbia Pictures                         117
# Twentieth Century Fox Film Corporation    109
# Relativity Media                           99
# New Line Cinema                            88
# Walt Disney Pictures                       82
# Village Roadshow Pictures                  63
# DreamWorks SKG                             62
# dtype: int64

# %%
answer_ls.append('Universal Pictures')

# %% [markdown]
# # 21. Какая студия сняла больше всего фильмов в 2015 году?
# Варианты ответа:
# 1. Universal Pictures
# 2. Paramount Pictures
# 3. Columbia Pictures
# 4. Warner Bros
# 5. Twentieth Century Fox Film Corporation

# %%
ss = pd.DataFrame(data[data.release_date.str.contains('2015')].production_companies.str.split('|').tolist())
ss.stack().value_counts().head(10)
# Out:
# Warner Bros.                              12
# Universal Pictures                        10
# Twentieth Century Fox Film Corporation     8
# Columbia Pictures                          7
# Paramount Pictures                         7
# TSG Entertainment                          6
# RatPac-Dune Entertainment                  5
# Blumhouse Productions                      5
# New Line Cinema                            5
# Legendary Pictures                         5
# dtype: int64

# %%
answer_ls.append('Warner Bros.')

# %% [markdown]
# # 22. Какая студия заработала больше всего денег в жанре комедий за все время?
# Варианты ответа:
# 1. Warner Bros
# 2. Universal Pictures (Universal)
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Walt Disney

# %%
ss = pd.DataFrame(data[data.genres.str.contains('Comedy')].production_companies.str.split('|').tolist())
ss.stack().value_counts().head(5)
# Out:
# Universal Pictures                        75
# Columbia Pictures                         62
# Warner Bros.                              46
# Walt Disney Pictures                      45
# Twentieth Century Fox Film Corporation    44
# dtype: int64

# %%
answer_ls.append("Universal Pictures")

# %% [markdown]
# # 23. Какая студия заработала больше всего денег в 2012 году?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Columbia Pictures
# 4. Paramount Pictures
# 5. Lucasfilm

# %%
new_df = pd.DataFrame(columns = ['release_year', 'production_companies', 'profit', 'revenue','budget'])

def formnewframe(def_list):
    production_companies = def_list.production_companies.split('|')
    for i in production_companies:
        new_df.loc[len(new_df)] = [def_list.release_date,i,def_list.profit,def_list.revenue, def_list.budget ]
        
ndata = data[data['release_year'] == 2012]
for i in range(len(ndata)):
    formnewframe(ndata.iloc[i])
    
new_df.head(15)


new_df.groupby(['production_companies'])['revenue'].sum().sort_values(ascending=False).head(5)
# Out:
# production_companies
# Columbia Pictures     3468406608
# Universal Pictures    2901011579
# Warner Bros.          1869520056
# Relativity Media      1701593938
# Marvel Studios        1519557910
# Name: revenue, dtype: int64

# %%
answer_ls.append("Columbia Pictures")

# %% [markdown]
# # 24. Самый убыточный фильм от Paramount Pictures
# Варианты ответа:
#
# 1. K-19: The Widowmaker tt0267626
# 2. Next tt0435705
# 3. Twisted tt0315297
# 4. The Love Guru tt0811138
# 5. The Fighter tt0964517

# %%
ct = data[data['production_companies'].str.contains('Paramount Pictures')]
#ct.groupby(['production_companies'])['profit'].sum().sort_values(ascending=True).head(5)
ct
# Out:
#         imdb_id  popularity     budget    revenue  \
# 6     tt1340138    8.654359  155000000  440603537
# 24    tt1596363    4.648046   28000000  133346506
# 25    tt2381249    4.566713  150000000  682330139
# 76    tt1528854    1.904898   50000000  240360392
# 90    tt2436386    1.360926   12000000   32248241
# 94    tt2473510    1.338322   10000000   78099553
# 97    tt2279373    1.291013   74000000  311594032
# 118   tt0816692   24.949134  165000000  621752480
# 134   tt1291150    5.787396  125000000  477200000
# 137   tt2109248    4.983782  210000000  245500000
# 170   tt1267297    2.549403  100000000  243400000
# 171   tt1959490    2.526779  125000000  362637473
# 180   tt1205537    2.141491   60000000   50549107
# 235   tt2039393    0.350612   25000000   39171130
# 244   tt0796366    3.829570  150000000  385680446
# 250   tt0409459    3.038063  130000000  185258983
# 259   tt1046173    1.906998  175000000  302469017
# 317   tt1055369    0.813323  150000000  836297228
# ...

# %%
ct.groupby(['original_title'])['profit'].sum().sort_values(ascending=True).head(5)
# Out:
# original_title
# K-19: The Widowmaker   -64831034
# Timeline               -60519261
# Next                   -51788987
# Alfie                  -46604061
# Twisted                -24805000
# Name: profit, dtype: int64

# %%
answer_ls.append("K-19: The Widowmaker")

# %% [markdown]
# # 25. Какой Самый прибыльный год (заработали больше всего)?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2002
# 5. 2015

# %%
data.groupby(['release_year'])['profit'].sum().sort_values(ascending=False).head(10)
# Out:
# release_year
# 2015    18668572378
# 2014    16397812953
# 2012    16077001687
# 2013    15243179791
# 2011    14730241341
# 2009    13423744372
# 2010    13117292530
# 2008    11663881990
# 2007    11565911801
# 2004     9634180720
# Name: profit, dtype: int64

# %%
answer_ls.append("2015")

# %% [markdown]
# # 26. Какой Самый прибыльный год для студии Warner Bros?
# Варианты ответа:
# 1. 2014
# 2. 2008
# 3. 2012
# 4. 2010
# 5. 2015

# %%
ss = data[data.production_companies.str.contains('Warner Bros')]
ss.groupby(['release_year'])['profit'].sum().sort_values(ascending=False).head(10)
# Out:
# release_year
# 2014    2295464519
# 2007    2201675217
# 2008    2134595031
# 2010    1974712985
# 2011    1871393682
# 2003    1855493377
# 2009    1822454136
# 2013    1636453400
# 2004    1631933725
# 2005    1551980298
# Name: profit, dtype: int64

# %%
answer_ls.append("2014")

# %% [markdown]
# # 27. В каком месяце за все годы суммарно вышло больше всего фильмов?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
def toint(x):
    return(int(x))
    

ss = pd.DataFrame(data.release_date.str.split('/').tolist(), columns = ['mounth', 'day', 'year'])
ss['mounth'] = ss['mounth'].apply(toint)
ss.head(15)

films_mounth = ss.groupby('mounth')['day'].count().sort_values()
films_mounth
# Out:
# mounth
# 1     110
# 2     135
# 5     140
# 7     142
# 11    146
# 6     147
# 4     149
# 3     156
# 8     161
# 10    186
# 12    191
# 9     227
# Name: day, dtype: int64

# %%
answer_ls.append("Сентябрь")

# %% [markdown]
# # 28. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)
# Варианты ответа:
# 1. 345
# 2. 450
# 3. 478
# 4. 523
# 5. 381

# %%
films_mounth.loc[6] + films_mounth.loc[7] + films_mounth.loc[8]
# Out:
# 450

# %%
answer_ls.append(450)

# %% [markdown]
# # 29. Какой режисер выпускает (суммарно по годам) больше всего фильмов зимой?
# Варианты ответов:
# 1. Steven Soderbergh
# 2. Christopher Nolan
# 3. Clint Eastwood
# 4. Ridley Scott
# 5. Peter Jackson

# %%
def toint(x):
    return(int(x))
    

ss = pd.DataFrame(data.release_date.str.split('/').tolist(), columns = ['mounth', 'day', 'year'])
ss['mounth'] = ss['mounth'].apply(toint)
ss.head(15)

films_mounth = ss.groupby('mounth')['day'].count().sort_values()
films_mounth
# Out:
# mounth
# 1     110
# 2     135
# 5     140
# 7     142
# 11    146
# 6     147
# 4     149
# 3     156
# 8     161
# 10    186
# 12    191
# 9     227
# Name: day, dtype: int64

# %%
new_df = pd.DataFrame(columns = ['director', 'release_date', 'imdb_id', 'original_title'])

def formnewframe(def_list):
    directors = def_list.director.split('|')
    for i in directors:
        new_df.loc[len(new_df)] = [i,def_list.release_date,def_list.imdb_id,def_list.original_title]
        


for i in range(len(data)):
    formnewframe(data.iloc[i])
    
new_df.head(15)

ss = pd.DataFrame(data.release_date.str.split('/').tolist(),data.director, columns = ['mounth', 'day', 'year'])
ss['mounth'] = ss['mounth'].apply(toint)

nss = ss[(ss['mounth'] == 12) | (ss['mounth'] == 1)  | (ss['mounth'] == 2)]
nss.head(15)
nss.groupby(['director'])['mounth'].count().sort_values(ascending=False).head(5)
# Out:
# director
# Peter Jackson        7
# Clint Eastwood       6
# Steven Soderbergh    6
# Shawn Levy           4
# Adam Shankman        4
# Name: mounth, dtype: int64

# %%
answer_ls.append("Peter Jackson")

# %% [markdown]
# # 30. Какой месяц чаще всего по годам самый прибыльный?
# Варианты ответа:
# 1. Январь
# 2. Июнь
# 3. Декабрь
# 4. Сентябрь
# 5. Май

# %%
def toint(x):
    return(int(x))
    

ss = pd.DataFrame(data.release_date.str.split('/').tolist(), data.profit)


ss.columns = ['mounth','day','year']
ss = ss.reset_index()
ss['profit'] = ss['profit'].apply(toint)
ss['mounth'] = ss['mounth'].apply(toint)
ss['year'] = ss['year'].apply(toint)
pt = ss.pivot_table(values=['profit'],
index=['year'],
columns=['mounth'],
aggfunc='sum')

pt.groupby(['year']).max().idxmax(axis=1)

#ss.groupby(['year', 'mounth'])['profit'].aggregate('sum').unstack()
# Out:
# year
# 2000    (profit, 12)
# 2001    (profit, 12)
# 2002    (profit, 12)
# 2003     (profit, 5)
# 2004     (profit, 5)
# 2005     (profit, 5)
# 2006     (profit, 6)
# 2007     (profit, 6)
# 2008     (profit, 6)
# 2009    (profit, 12)
# 2010     (profit, 6)
# 2011     (profit, 7)
# 2012     (profit, 6)
# 2013     (profit, 6)
# 2014     (profit, 5)
# 2015     (profit, 6)
# dtype: object

# %%
answer_ls.append("Июнь")

# %% [markdown]
# # 31. Названия фильмов какой студии в среднем самые длинные по количеству символов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
new_df = pd.DataFrame(columns = ['production_companies', 'original_title'])

def formnewframe(def_list):
    production_companies = def_list.production_companies.split('|')
    for i in production_companies:
        new_df.loc[len(new_df)] = [i, def_list.original_title]
        


for i in range(len(data)):
    formnewframe(data.iloc[i])
    

new_df.head(15)
# Out:
#           production_companies                original_title
# 0            Universal Studios                Jurassic World
# 1         Amblin Entertainment                Jurassic World
# 2           Legendary Pictures                Jurassic World
# 3      Fuji Television Network                Jurassic World
# 4                       Dentsu                Jurassic World
# 5    Village Roadshow Pictures            Mad Max: Fury Road
# 6   Kennedy Miller Productions            Mad Max: Fury Road
# 7         Summit Entertainment                     Insurgent
# 8             Mandeville Films                     Insurgent
# 9      Red Wagon Entertainment                     Insurgent
# 10                     NeoReel                     Insurgent
# 11                   Lucasfilm  Star Wars: The Force Awakens
# 12       Truenorth Productions  Star Wars: The Force Awakens
# 13                   Bad Robot  Star Wars: The Force Awakens
# ...

# %%
new_df['av_len'] = new_df['original_title'].apply(lambda x : len(x))
new_df.head(15)
new_df.groupby(['production_companies'])['av_len'].mean().sort_values(ascending=False).head(5)
# Out:
# production_companies
# Four By Two Productions      83.0
# Jim Henson Company, The      59.0
# Dos Corazones                47.0
# Polsky Films                 46.0
# Museum Canada Productions    46.0
# Name: av_len, dtype: float64

# %%
answer_ls.append("Four By Two Productions")

# %% [markdown]
# # 32. Названия фильмов какой студии в среднем самые длинные по количеству слов?
# Варианты ответа:
# 1. Universal Pictures (Universal)
# 2. Warner Bros
# 3. Jim Henson Company, The
# 4. Paramount Pictures
# 5. Four By Two Productions

# %%
new_df['qw_words'] = new_df['original_title'].apply(lambda x : len(x.split(' ')))
new_df.head(15)
new_df.groupby(['production_companies'])['qw_words'].mean().sort_values(ascending=False).head(5)
# Out:
# production_companies
# Four By Two Productions    12.0
# Jim Henson Company, The    10.0
# Polsky Films                9.0
# The Saul Zaentz Company     9.0
# Dos Corazones               9.0
# Name: qw_words, dtype: float64

# %%
answer_ls.append("Four By Two Productions")

# %% [markdown]
# # 33. Сколько разных слов используется в названиях фильмов?(без учета регистра)
# Варианты ответа:
# 1. 6540
# 2. 1002
# 3. 2461
# 4. 28304
# 5. 3432

# %%
import re
mdict = {}


for i in range(len(data)):
    currline = data['original_title'].iloc[i].split(" ")
    #надо будет убрать все точки и знаки
    #currline = re.findall('[\w]+', data['original_title'].iloc[i])
    #print(currline)
    
    for k in currline:
        mdict.setdefault(k.lower(),1)
            
    #i = i+1
    #if i>10: break;
    
    
print(len(mdict))    
#print(mdict)
# Out:
# 2462

# %%
answer_ls.append(2461)

# %% [markdown]
# # 34. Какие фильмы входят в 1 процент лучших по рейтингу?
# Варианты ответа:
# 1. Inside Out, Gone Girl, 12 Years a Slave
# 2. BloodRayne, The Adventures of Rocky & Bullwinkle
# 3. The Lord of the Rings: The Return of the King
# 4. 300, Lucky Number Slevin

# %%
#np.percentile()

data[data['vote_average']>data.quantile(0.99, numeric_only=True)['vote_average']]
# Out:
#         imdb_id  popularity     budget     revenue  \
# 9     tt2096673    6.326804  175000000   853708609
# 34    tt3170832    3.557846    6000000    35401758
# 118   tt0816692   24.949134  165000000   621752480
# 119   tt2015381   14.311205  170000000   773312399
# 125   tt2084970    8.110711   14000000   233555708
# 128   tt2267998    6.438727   61000000   369330363
# 138   tt2278388    4.930820   30000000   174600318
# 370   tt1375666    9.363643  160000000   825500000
# 600   tt0468569    8.466668  185000000  1001921825
# 873   tt0253474    2.364204   35000000   120072577
# 1082  tt0167260    7.122455   94000000  1118888979
# 1184  tt0993846    4.877927  100000000   392000694
# 1192  tt2024544    3.625529   20000000   187000000
# 1801  tt0209144    3.095625    9000000    39723096
#
#                                      original_title  \
# 9                                        Inside Out
# 34                                             Room
# ...

# %%
answer_ls.append("Inside Out, Gone Girl, 12 Years a Slave")

# %% [markdown]
# # 35. Какие актеры чаще всего снимаются в одном фильме вместе
# Варианты ответа:
# 1. Johnny Depp & Helena Bonham Carter
# 2. Hugh Jackman & Ian McKellen
# 3. Vin Diesel & Paul Walker
# 4. Adam Sandler & Kevin James
# 5. Daniel Radcliffe & Rupert Grint

# %%
combinations() из библиотеки itertools

# %%
from itertools import combinations
for i in range(len(data)):
    c_list = data['cast'].iloc[i].split("|")
    d = d + list(combinations(c_list, 2))
    
df_test = pd.DataFrame.from_records(d)
df_test.columns = ['actor1','actor2']
df_test['col'] = 0
df_test.head()
# Out:
#          actor1          actor2  col
# 0    Susan Ward    Lori Heuring    0
# 1    Susan Ward  Matthew Settle    0
# 2    Susan Ward   Nathan Bexton    0
# 3    Susan Ward     Tess Harper    0
# 4  Lori Heuring  Matthew Settle    0

# %%
df_test.groupby(['actor1','actor2']).count().sort_values(by = 'col', ascending=False).head(5)
# Out:
#                                        col
# actor1           actor2
# Daniel Radcliffe Rupert Grint          144
#                  Emma Watson           144
# Rupert Grint     Emma Watson           126
# Ben Stiller      Owen Wilson           108
# Johnny Depp      Helena Bonham Carter  108

# %%
answer_ls.append("Daniel Radcliffe & Rupert Grint")

# %%
data[data.cast.str.contains("Daniel Radcliffe")]['cast']
# Out:
# 103     James McAvoy|Daniel Radcliffe|Jessica Brown Fi...
# 242     Daniel Radcliffe|Rupert Grint|Emma Watson|Tom ...
# 374     Daniel Radcliffe|Emma Watson|Rupert Grint|Ralp...
# 498     Daniel Radcliffe|Rupert Grint|Emma Watson|John...
# 723     Daniel Radcliffe|Rupert Grint|Emma Watson|Alan...
# 865     Daniel Radcliffe|Rupert Grint|Emma Watson|Kenn...
# 1041    Daniel Radcliffe|CiarÃ¡n Hinds|Sidney Johnston...
# 1237    Daniel Radcliffe|Zoe Kazan|Rafe Spall|Megan Pa...
# 1313    Daniel Radcliffe|Rupert Grint|Emma Watson|Ralp...
# 1561    Daniel Radcliffe|Rupert Grint|Emma Watson|Gary...
# 1671    Daniel Radcliffe|Rupert Grint|Emma Watson|Mich...
# Name: cast, dtype: object

# %% [markdown]
# # 36. У какого из режиссеров выше вероятность выпустить фильм в прибыли? (5 баллов)101
# Варианты ответа:
# 1. Quentin Tarantino
# 2. Steven Soderbergh
# 3. Robert Rodriguez
# 4. Christopher Nolan
# 5. Clint Eastwood

# %%
data.head()
# Out:
#      imdb_id  popularity     budget     revenue                original_title  \
# 0  tt0369610   32.985763  150000000  1513528810                Jurassic World
# 1  tt1392190   28.419936  150000000   378436354            Mad Max: Fury Road
# 2  tt2908446   13.112507  110000000   295238201                     Insurgent
# 3  tt2488496   11.173104  200000000  2068178225  Star Wars: The Force Awakens
# 4  tt2820852    9.335014  190000000  1506249360                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# ...

# %%
new_df = pd.DataFrame(columns = ['director', 'profit', 'imdb_id', 'budget'])

def formnewframe(def_list):
    directors = def_list.director.split('|')
    for i in directors:
        new_df.loc[len(new_df)] = [i,def_list.profit,def_list.imdb_id,def_list.budget]
        


for i in range(len(data)):
    formnewframe(data.iloc[i])
    
new_df.head(15)
# Out:
#                           director      profit    imdb_id     budget
# 0                  Colin Trevorrow  1363528810  tt0369610  150000000
# 1                    George Miller   228436354  tt1392190  150000000
# 2                 Robert Schwentke   185238201  tt2908446  110000000
# 3                      J.J. Abrams  1868178225  tt2488496  200000000
# 4                        James Wan  1316249360  tt2820852  190000000
# 5   Alejandro GonzÃ¡lez IÃ±Ã¡rritu   397950503  tt1663202  135000000
# 6                      Alan Taylor   285603537  tt1340138  155000000
# 7                     Ridley Scott   487380321  tt3659388  108000000
# 8                       Kyle Balda  1082730962  tt2293640   74000000
# 9                    Pierre Coffin  1082730962  tt2293640   74000000
# 10                     Pete Docter   678708609  tt2096673  175000000
# 11                      Sam Mendes   635674609  tt2379713  245000000
# 12                  Lana Wachowski     7987720  tt1617661  176000003
# ...

# %%
new_df.groupby('director').sepalLength.agg([
    lambda x: x.max(), 
    lambda x: x.min()
    ]).to_markdown())

# %%
allfilms = new_df.groupby('director').agg({'profit': 'count'})
pr_films = new_df[new_df['profit']>0].groupby('director').agg({'profit': 'count'})
t = allfilms.merge(pr_films, how='left',left_on='director', right_on='director')
t['profit_y'].fillna(0, inplace=True)
t['suc'] = t['profit_y']/t['profit_x']
t.sort_values(['profit_x',"suc"],ascending=False).head(20)
# Out:
#                     profit_x  profit_y       suc
# director
# Steven Soderbergh         13      10.0  0.769231
# Ridley Scott              12      12.0  1.000000
# Clint Eastwood            12      10.0  0.833333
# Robert Rodriguez          11       8.0  0.727273
# Steven Spielberg          10      10.0  1.000000
# Shawn Levy                10       9.0  0.900000
# Peter Farrelly            10       8.0  0.800000
# Tim Burton                 9       9.0  1.000000
# Bobby Farrelly             9       7.0  0.777778
# Antoine Fuqua              8       8.0  1.000000
# Brett Ratner               8       8.0  1.000000
# Christopher Nolan          8       8.0  1.000000
# Michael Bay                8       8.0  1.000000
# Peter Jackson              8       8.0  1.000000
# Adam Shankman              8       7.0  0.875000
# M. Night Shyamalan         8       7.0  0.875000
# Todd Phillips              8       7.0  0.875000
# Gore Verbinski             8       6.0  0.750000
# ...

# %%
answer_ls.append("Christopher Nolan")

# %% [markdown]
# # Submission

# %%
len(answer_ls)
# Out:
# 38

# %%
pd.DataFrame({'Id':range(1,len(answer_ls)+1), 'Answer':answer_ls}, columns=['Id', 'Answer'])
# Out:
#     Id                                             Answer
# 0    1  491    The Warrior's Way
# Name: original_title,...
# 1    2  491    The Warrior's Way
# Name: original_title,...
# 2    3  1158    Gods and Generals
# Name: original_title...
# 3    4  769    Winnie the Pooh
# Name: original_title, d...
# 4    5                                                110
# 5    6                                                106
# 6    7  239    Avatar
# Name: original_title, dtype: object
# 7    8  491    The Warrior's Way
# Name: original_title,...
# 8    9  imdb_id                 1478
# popularity       ...
# 9   10                                    The Dark Knight
# 10  11                                    The Lone Ranger
# 11  12                                              Drama
# 12  13                                              Drama
# 13  14                                  Steven Soderbergh
# 14  15                                       Ridley Scott
# ...
